# %%
# Import the relavant libraries

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the World Population Data
dataset = pd.read_csv('world_pop.csv')

# %%
# Display the first five columns in the dataset

dataset.head()
# Out:
#    Unnamed: 0         country   year_1960   year_1961   year_1962   year_1963  \
# 0           1     Afghanistan   8996967.0   9169406.0   9351442.0   9543200.0
# 1           2         Albania   1608800.0   1659800.0   1711319.0   1762621.0
# 2           3         Algeria  11057864.0  11336336.0  11619828.0  11912800.0
# 3           4  American Samoa     20127.0     20605.0     21246.0     22029.0
# 4           5         Andorra     13410.0     14378.0     15379.0     16407.0
#
#     year_1964   year_1965   year_1966   year_1967  ...  year_2011   year_2012  \
# 0   9744772.0   9956318.0  10174840.0  10399936.0  ...   30117411  31161378.0
# 1   1814135.0   1864791.0   1914573.0   1965598.0  ...    2905195   2900401.0
# 2  12221675.0  12550880.0  12902626.0  13275020.0  ...   36661438  37383899.0
# 3     22850.0     23675.0     24473.0     25235.0  ...      55755     55669.0
# 4     17466.0     18542.0     19646.0     20760.0  ...      83748     82427.0
#
# ...

# %%
# To clean up the data a little, I want to drop the first column and rename the other columns

# Drop the first column (index 0)
dataset_edited = dataset.drop(dataset.columns[0], axis=1)

# %%
# Rename the columns
dataset_edited = dataset_edited.rename(columns=lambda x: x.replace('year_', ''))

# %%
dataset_edited.head()
# Out:
#           country        1960        1961        1962        1963        1964  \
# 0     Afghanistan   8996967.0   9169406.0   9351442.0   9543200.0   9744772.0
# 1         Albania   1608800.0   1659800.0   1711319.0   1762621.0   1814135.0
# 2         Algeria  11057864.0  11336336.0  11619828.0  11912800.0  12221675.0
# 3  American Samoa     20127.0     20605.0     21246.0     22029.0     22850.0
# 4         Andorra     13410.0     14378.0     15379.0     16407.0     17466.0
#
#          1965        1966        1967        1968  ...      2011        2012  \
# 0   9956318.0  10174840.0  10399936.0  10637064.0  ...  30117411  31161378.0
# 1   1864791.0   1914573.0   1965598.0   2022272.0  ...   2905195   2900401.0
# 2  12550880.0  12902626.0  13275020.0  13663581.0  ...  36661438  37383899.0
# 3     23675.0     24473.0     25235.0     25980.0  ...     55755     55669.0
# 4     18542.0     19646.0     20760.0     21886.0  ...     83748     82427.0
#
# ...

# %%
dataset_edited.dtypes
# Out:
# country     object
# 1960       float64
# 1961       float64
# 1962       float64
# 1963       float64
#             ...
# 2016       float64
# 2017       float64
# 2018       float64
# 2019       float64
# 2020       float64
# Length: 62, dtype: object

# %%
dataset_edited.tail()
# Out:
#                    country       1960       1961       1962       1963  \
# 211  Virgin Islands (U.S.)    32500.0    34300.0    35000.0    39800.0
# 212     West Bank and Gaza        NaN        NaN        NaN        NaN
# 213            Yemen, Rep.  5315351.0  5393034.0  5473671.0  5556767.0
# 214                 Zambia  3070780.0  3164330.0  3260645.0  3360099.0
# 215               Zimbabwe  3776679.0  3905038.0  4039209.0  4178726.0
#
#           1964       1965       1966       1967       1968  ...      2011  \
# 211    40800.0    43500.0    46200.0    49100.0    55700.0  ...    108290
# 212        NaN        NaN        NaN        NaN        NaN  ...   3882986
# 213  5641598.0  5727745.0  5816241.0  5907873.0  6001858.0  ...  23807586
# 214  3463211.0  3570466.0  3681953.0  3797877.0  3918872.0  ...  14023199
# 215  4322854.0  4471178.0  4623340.0  4779825.0  4941901.0  ...  12894323
#
#            2012        2013        2014        2015        2016        2017  \
# ...

# %%
# Calculate the sum of population for each year
year_sums = dataset_edited.iloc[:, 1:].sum(axis=0)

# Create a new row to store the total population
total_row = pd.DataFrame(year_sums).T
total_row.insert(0, 'country', 'Total')
total_row.reset_index(drop=True, inplace=True)

# Append the total row to the dataset
dataset_edited = dataset_edited.append(total_row, ignore_index=True)
# Out:
# C:\Users\victor.sabo\AppData\Local\Temp\ipykernel_22968\1659435029.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataset_edited = dataset_edited.append(total_row, ignore_index=True)

# %%
dataset_edited.tail()
# Out:
#                 country          1960          1961          1962  \
# 212  West Bank and Gaza           NaN           NaN           NaN
# 213         Yemen, Rep.  5.315351e+06  5.393034e+06  5.473671e+06
# 214              Zambia  3.070780e+06  3.164330e+06  3.260645e+06
# 215            Zimbabwe  3.776679e+06  3.905038e+06  4.039209e+06
# 216               Total  3.021345e+09  3.060413e+09  3.112997e+09
#
#              1963          1964          1965          1966          1967  \
# 212           NaN           NaN           NaN           NaN           NaN
# 213  5.556767e+06  5.641598e+06  5.727745e+06  5.816241e+06  5.907873e+06
# 214  3.360099e+06  3.463211e+06  3.570466e+06  3.681953e+06  3.797877e+06
# 215  4.178726e+06  4.322854e+06  4.471178e+06  4.623340e+06  4.779825e+06
# 216  3.177701e+09  3.242790e+09  3.309282e+09  3.378914e+09  3.448293e+09
#
#              1968  ...          2011          2012          2013  \
# ...

# %%
# Set the option to display numbers with commas
pd.options.display.float_format = '{:,.0f}'.format

# %%
dataset_edited.tail()
# Out:
#                 country          1960          1961          1962  \
# 212  West Bank and Gaza           NaN           NaN           NaN
# 213         Yemen, Rep.     5,315,351     5,393,034     5,473,671
# 214              Zambia     3,070,780     3,164,330     3,260,645
# 215            Zimbabwe     3,776,679     3,905,038     4,039,209
# 216               Total 3,021,344,938 3,060,413,319 3,112,997,065
#
#              1963          1964          1965          1966          1967  \
# 212           NaN           NaN           NaN           NaN           NaN
# 213     5,556,767     5,641,598     5,727,745     5,816,241     5,907,873
# 214     3,360,099     3,463,211     3,570,466     3,681,953     3,797,877
# 215     4,178,726     4,322,854     4,471,178     4,623,340     4,779,825
# 216 3,177,700,956 3,242,790,380 3,309,282,080 3,378,913,694 3,448,292,889
#
#              1968  ...          2011          2012          2013  \
# ...

# %%
# Visualizing population growth

# Extract relevant columns
years = dataset_edited.columns[1:]
population = dataset_edited.iloc[-1, 1:]

# Create a line plot using seaborn
plt.figure(figsize=(10, 5))
sns.lineplot(x=years, y=population, color='blue')
plt.xlabel('Year')
plt.ylabel('Population (billion)')
plt.xticks(rotation=90)
plt.grid(False)


# Save the plot as a JPEG file
plt.savefig('population_growth.jpg', format='jpeg')


plt.show()

# %%
# Create a dictionary mapping countries to continents
country_to_continent = {
    'Afghanistan': 'Asia',
    'Albania' : 'Europe',
    'Algeria': 'Africa',
    'American Samoa': 'Oceania',
    'Andorra': 'Europe',
    'Angola': 'Africa',
    'Antigua and Barbuda': 'North America',
    'Argentina': 'South America',
    'Armenia': 'Asia',
    'Aruba': 'North America',
    'Australia': 'Oceania',
    'Austria': 'Europe',
    'Azerbaijan': 'Asia',
    "Bahamas, The": 'North America',
    'Bahrain': 'Asia',
    'Bangladesh': 'Asia',
    'Barbados': 'North America',
    'Belarus': 'Europe',
    'Belgium': 'Europe',
    'Belize': 'North America',
    'Benin': 'Africa',
    'Bermuda': 'North America',
    'Bhutan': 'Asia',
    'Bolivia': 'South America',
    'Bosnia and Herzegovina': 'Europe',
    'Botswana': 'Africa',
    'Brazil': 'South America',
    'British Virgin Islands': 'North America',
    'Brunei Darussalam': 'Asia',
    'Bulgaria': 'Europe',
    'Burkina Faso': 'Africa',
    'Burundi': 'Africa',
    'Cabo Verde': 'Africa',
    'Cambodia': 'Asia',
    'Cameroon': 'Africa',
    'Canada': 'North America',
    'Cayman Islands': 'North America',
    'Central African Republic': 'Africa',
    'Chad': 'Africa',
    'Chile': 'South America',
    'China': 'Asia',
    'Colombia': 'South America',
    'Comoros': 'Africa',
    'Congo, Dem. Rep.': 'Africa',
    'Congo, Rep.': 'Africa',
    'Costa Rica': 'North America',
    "Cote d'Ivoire": 'Africa',
    'Croatia': 'Europe',
    'Cuba': 'North America',
    'Curacao': 'North America',
    'Cyprus': 'Asia',
    'Czech Republic': 'Europe',
    'Denmark': 'Europe',
    'Djibouti': 'Africa',
    'Dominica': 'North America',
    'Dominican Republic': 'North America',
    'Ecuador': 'South America',
    'Egypt, Arab Rep.': 'Africa',
    'El Salvador': 'North America',
    'Equatorial Guinea': 'Africa',
    'Eritrea': 'Africa',
    'Estonia': 'Europe',
    'Eswatini': 'Africa',
    'Ethiopia': 'Africa',
    'Faroe Islands': 'Europe',
    'Fiji': 'Oceania',
    'Finland': 'Europe',
    'France': 'Europe',
    'French Polynesia': 'Oceania',
    'Gabon': 'Africa',
    'Gambia, The': 'Africa',
    'Georgia': 'Asia',
    'Germany': 'Europe',
    'Ghana': 'Africa',
    'Gibraltar': 'Europe',
    'Greece': 'Europe',
    'Greenland': 'North America',
    'Grenada': 'North America',
    'Guam': 'Oceania',
    'Guatemala': 'North America',
    'Guinea': 'Africa',
    'Guinea-Bissau': 'Africa',
    'Guyana': 'South America',
    'Haiti': 'North America',
    'Honduras': 'North America',
    'Hong Kong SAR, China': 'Asia',
    'Hungary': 'Europe',
    'Iceland': 'Europe',
    'India': 'Asia',
    'Indonesia': 'Asia',
    'Iran, Islamic Rep.': 'Asia',
    'Iraq': 'Asia',
    'Ireland': 'Europe',
    'Isle of Man': 'Europe',
    'Israel': 'Asia',
    'Italy': 'Europe',
    'Jamaica': 'North America',
    'Japan': 'Asia',
    'Jordan': 'Asia',
    'Kazakhstan': 'Asia',
    'Kenya': 'Africa',
    'Kiribati': 'Oceania',
    "Korea, Dem. People's Rep.": 'Asia',
    'Korea, Rep.': 'Asia',
    'Kosovo': 'Europe',
    'Kuwait': 'Asia',
    'Kyrgyz Republic': 'Asia',
    'Lao PDR': 'Asia',
    'Latvia': 'Europe',
    'Lebanon': 'Asia',
    'Lesotho': 'Africa',
    'Liberia': 'Africa',
    'Libya': 'Africa',
    'Liechtenstein': 'Europe',
    'Lithuania': 'Europe',
    'Luxembourg': 'Europe',
    'Macao SAR, China': 'Asia',
    'Madagascar': 'Africa',
    'Malawi': 'Africa',
    'Malaysia': 'Asia',
    'Maldives': 'Asia',
    'Mali': 'Africa',
    'Malta': 'Europe',
    'Marshall Islands': 'Oceania',
    'Mauritania': 'Africa',
    'Mauritius': 'Africa',
    'Mexico': 'North America',
    'Micronesia, Fed. Sts.': 'Oceania',
    'Moldova': 'Europe',
    'Monaco': 'Europe',
    'Mongolia': 'Asia',
    'Montenegro': 'Europe',
    'Morocco': 'Africa',
    'Mozambique': 'Africa',
    'Myanmar': 'Asia',
    'Namibia': 'Africa',
    'Nauru': 'Oceania',
    'Nepal': 'Asia',
    'Netherlands': 'Europe',
    'New Caledonia': 'Oceania',
    'New Zealand': 'Oceania',
    'Nicaragua': 'North America',
    'Niger': 'Africa',
    'Nigeria': 'Africa',
    'North Macedonia': 'Europe',
    'Northern Mariana Islands': 'Oceania',
    'Norway': 'Europe',
    'Oman': 'Asia',
    'Pakistan': 'Asia',
    'Palau': 'Oceania',
    'Panama': 'North America',
    'Papua New Guinea': 'Oceania',
    'Paraguay': 'South America',
    'Peru': 'South America',
    'Philippines': 'Asia',
    'Poland': 'Europe',
    'Portugal': 'Europe',
    'Puerto Rico': 'North America',
    'Qatar': 'Asia',
    'Romania': 'Europe',
    'Russian Federation': 'Europe',
    'Rwanda': 'Africa',
    'Samoa': 'Oceania',
    'San Marino': 'Europe',
    'Sao Tome and Principe': 'Africa',
    'Saudi Arabia': 'Asia',
    'Senegal': 'Africa',
    'Serbia': 'Europe',
    'Seychelles': 'Africa',
    'Sierra Leone': 'Africa',
    'Singapore': 'Asia',
    'Sint Maarten (Dutch part)': 'North America',
    'Slovak Republic': 'Europe',
    'Slovenia': 'Europe',
    'Solomon Islands': 'Oceania',
    'Somalia': 'Africa',
    'South Africa': 'Africa',
    'South Sudan': 'Africa',
    'Spain': 'Europe',
    'Sri Lanka': 'Asia',
    'St. Kitts and Nevis': 'North America',
    'St. Lucia': 'North America',
    'St. Martin (French part)': 'North America',
    'St. Vincent and the Grenadines': 'North America',
    'Sudan': 'Africa',
    'Suriname': 'South America',
    'Sweden': 'Europe',
    'Switzerland': 'Europe',
    'Syrian Arab Republic': 'Asia',
    'Tajikistan': 'Asia',
    'Tanzania': 'Africa',
    'Thailand': 'Asia',
    'Timor-Leste': 'Asia',
    'Togo': 'Africa',
    'Tonga': 'Oceania',
    'Trinidad and Tobago': 'North America',
    'Tunisia': 'Africa',
    'Turkey': 'Asia',
    'Turkmenistan': 'Asia',
    'Turks and Caicos Islands': 'North America',
    'Tuvalu': 'Oceania',
    'Uganda': 'Africa',
    'Ukraine': 'Europe',
    'United Arab Emirates': 'Asia',
    'United Kingdom': 'Europe',
    'United States': 'North America',
    'Uruguay': 'South America',
    'Uzbekistan': 'Asia',
    'Vanuatu': 'Oceania',
    'Venezuela, RB': 'South America',
    'Vietnam': 'Asia',
    'Virgin Islands (U.S.)': 'North America',
    'West Bank and Gaza': 'Asia',
    'Yemen, Rep.': 'Asia',
    'Zambia': 'Africa',
    'Zimbabwe': 'Africa',
}

# Create a new column 'Continent' and map the values based on the country
dataset_edited['Continent'] = dataset_edited['country'].map(country_to_continent)

# Print the updated DataFrame
print(dataset_edited)
# Out:
#                 country          1960          1961          1962  \
# 0           Afghanistan     8,996,967     9,169,406     9,351,442
# 1               Albania     1,608,800     1,659,800     1,711,319
# 2               Algeria    11,057,864    11,336,336    11,619,828
# 3        American Samoa        20,127        20,605        21,246
# 4               Andorra        13,410        14,378        15,379
# ..                  ...           ...           ...           ...
# 212  West Bank and Gaza           NaN           NaN           NaN
# 213         Yemen, Rep.     5,315,351     5,393,034     5,473,671
# 214              Zambia     3,070,780     3,164,330     3,260,645
# 215            Zimbabwe     3,776,679     3,905,038     4,039,209
# 216               Total 3,021,344,938 3,060,413,319 3,112,997,065
#
#              1963          1964          1965          1966          1967  \
# 0       9,543,200     9,744,772     9,956,318    10,174,840    10,399,936
# ...

# %%
dataset_edited.Continent.isnull().sum()
# Out:
# 1

# %%
# Identify rows with NaN values
nan_rows = dataset_edited[dataset_edited.isnull().any(axis=1)]

# Display the rows with NaN values
print(nan_rows)
# Out:
#                 country          1960          1961          1962  \
# 60              Eritrea     1,007,586     1,033,320     1,060,489
# 105              Kuwait       269,026       300,581       337,346
# 212  West Bank and Gaza           NaN           NaN           NaN
# 216               Total 3,021,344,938 3,060,413,319 3,112,997,065
#
#              1963          1964          1965          1966          1967  \
# 60      1,088,859     1,118,152     1,148,188     1,178,875     1,210,304
# 105       378,756       423,900       472,032       523,169       577,164
# 212           NaN           NaN           NaN           NaN           NaN
# 216 3,177,700,956 3,242,790,380 3,309,282,080 3,378,913,694 3,448,292,889
#
#              1968  ...          2012          2013          2014  \
# 60      1,242,633  ...           NaN           NaN           NaN
# 105       632,911  ...     3,348,852     3,526,382     3,690,939
# ...

# %%
# Define the column names for the years in your dataset
year_columns = ['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970', 
                '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', 
                '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', 
                '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', 
                '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', 
                '2015', '2016', '2017', '2018', '2019', '2020']

# Group the data by continent and sum the population figures for each year
continent_pop = dataset_edited.groupby('Continent')[year_columns].sum()

# Reset the index to make the continent column a regular column
continent_pop = continent_pop.reset_index()

# Print the resulting dataset
print(continent_pop)
# Out:
#        Continent          1960          1961          1962          1963  \
# 0         Africa   282,962,756   289,804,889   296,899,075   304,243,843
# 1           Asia 1,698,719,232 1,715,303,902 1,744,857,569 1,786,271,448
# 2         Europe   605,154,128   610,996,645   617,067,553   623,184,588
# 3  North America   269,834,195   275,253,260   280,554,502   285,787,750
# 4        Oceania    16,023,119    16,353,964    16,756,010    17,098,297
# 5  South America   148,651,508   152,700,659   156,862,356   161,115,030
#
#            1964          1965          1966          1967          1968  ...  \
# 0   311,834,377   319,670,140   327,757,616   336,108,767   344,734,837  ...
# 1 1,827,826,387 1,870,928,204 1,917,889,653 1,964,661,020 2,012,930,443  ...
# 2   629,225,053   635,042,919   639,913,749   644,614,377   649,065,313  ...
# 3   291,019,039   296,048,679   300,970,377   305,811,766   310,505,217  ...
# ...

# %%
# Identify rows with NaN values
nan_rows = continent_pop[continent_pop.isnull().any(axis=1)]

# Display the rows with NaN values
print(nan_rows)
# Out:
# Empty DataFrame
# Columns: [0, 1, 2, 3, 4, 5]
# Index: []

# %%
dataset_edited.Continent.unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'Oceania', 'North America',
#        'South America', nan], dtype=object)

# %%
# Set the option to display numbers with commas
pd.options.display.float_format = '{:,.0f}'.format

# %%
continent_pop = continent_pop.T

# %%
continent_pop
# Out:
#        Continent          1960          1961          1962          1963  \
# 0         Africa   282,962,756   289,804,889   296,899,075   304,243,843
# 1           Asia 1,698,719,232 1,715,303,902 1,744,857,569 1,786,271,448
# 2         Europe   605,154,128   610,996,645   617,067,553   623,184,588
# 3  North America   269,834,195   275,253,260   280,554,502   285,787,750
# 4        Oceania    16,023,119    16,353,964    16,756,010    17,098,297
# 5  South America   148,651,508   152,700,659   156,862,356   161,115,030
#
#            1964          1965          1966          1967          1968  ...  \
# 0   311,834,377   319,670,140   327,757,616   336,108,767   344,734,837  ...
# 1 1,827,826,387 1,870,928,204 1,917,889,653 1,964,661,020 2,012,930,443  ...
# 2   629,225,053   635,042,919   639,913,749   644,614,377   649,065,313  ...
# 3   291,019,039   296,048,679   300,970,377   305,811,766   310,505,217  ...
# ...

# %%
continent_pop.to_excel('output.xlsx', index=False)

# %%
# Create a list of continents
continents = ['Africa', 'Asia', 'Europe', 'North America', 'Oceania', 'South America']

# Plot the population trend for each continent
plt.figure(figsize=(10, 5))
for continent in continents:
    # Get the population data for the continent
    continent_data = continent_pop[continent_pop['Continent'] == continent].drop('Continent', axis=1)
    
    # Reshape the data to long format
    continent_data = continent_data.melt(var_name='Year', value_name='Population')
    
    # Plot the population data using seaborn lineplot
    sns.lineplot(data=continent_data, x='Year', y='Population', label=continent)

# Set the x-axis and y-axis labels
plt.xlabel('Year')
plt.ylabel('Population (billion)')
plt.xticks(rotation=90)

# Set the title of the plot
plt.legend()

# Save the plot as a JPEG file
plt.savefig('continental_growth.jpg', format='jpeg')

plt.show()

# %%
# Set the 'Continent' column as the index
continent_pop.set_index('Continent', inplace=True)

# Calculate the yearly population changes and remove the first column (1960) from the DataFrame 
continent_change = continent_pop.diff(axis=1)
continent_change = continent_change.drop(columns='1960')

# Reset the index
continent_change.reset_index(inplace=True)

# %%
continent_change
# Out:
#        Continent       1961       1962       1963       1964       1965  \
# 0         Africa  6,842,133  7,094,186  7,344,768  7,590,534  7,835,763
# 1           Asia 16,584,670 29,553,667 41,413,879 41,554,939 43,101,817
# 2         Europe  5,842,517  6,070,908  6,117,035  6,040,465  5,817,866
# 3  North America  5,419,065  5,301,242  5,233,248  5,231,289  5,029,640
# 4        Oceania    330,845    402,046    342,287    358,056    353,581
# 5  South America  4,049,151  4,161,697  4,252,674  4,314,141  4,353,033
#
#         1966       1967       1968       1969  ...       2011       2012  \
# 0  8,087,476  8,351,151  8,626,070  8,914,449  ... 27,081,093 24,663,300
# 1 46,961,449 46,771,367 48,269,423 50,507,468  ... 44,463,702 43,805,605
# 2  4,870,830  4,700,628  4,450,936  4,313,848  ...   -316,418  1,272,808
# 3  4,921,698  4,841,389  4,693,451  4,671,572  ...  5,124,725  5,184,175
# 4    402,658    290,354    330,097    378,268  ...    536,374    609,543
# ...

# %%
# Create a list of continents
continents = ['Africa', 'Asia', 'Europe', 'North America', 'Oceania', 'South America']

# Plot the population trend for each continent
plt.figure(figsize=(10, 5))
for continent in continents:
    # Get the population data for the continent
    continent_change_data = continent_change[continent_change['Continent'] == continent].drop('Continent', axis=1)
    
    # Reshape the data to long format
    continent_change_data = continent_change_data.melt(var_name='Year', value_name='Population')
    
    # Plot the population data using seaborn lineplot
    sns.lineplot(data=continent_change_data, x='Year', y='Population', label=continent)

# Set the x-axis and y-axis labels
plt.xlabel('Year')
plt.ylabel('Population (million)')
plt.xticks(rotation=90)

# Save the plot as a JPEG file
plt.savefig('continental_change.jpg', format='jpeg')

plt.show()

# %%
# Drop the first row with missing growth rate values
continent_pop_change = continent_pop.dropna()

# %%
continent_pop_change
# Out:
#        Continent          1960          1961          1962          1963  \
# 1           Asia 1,698,719,232 1,715,303,902 1,744,857,569 1,786,271,448
# 2         Europe   605,154,128   610,996,645   617,067,553   623,184,588
# 3  North America   269,834,195   275,253,260   280,554,502   285,787,750
# 4        Oceania    16,023,119    16,353,964    16,756,010    17,098,297
# 5  South America   148,651,508   152,700,659   156,862,356   161,115,030
#
#            1964          1965          1966          1967          1968  ...  \
# 1 1,827,826,387 1,870,928,204 1,917,889,653 1,964,661,020 2,012,930,443  ...
# 2   629,225,053   635,042,919   639,913,749   644,614,377   649,065,313  ...
# 3   291,019,039   296,048,679   300,970,377   305,811,766   310,505,217  ...
# 4    17,456,353    17,809,934    18,212,592    18,502,946    18,833,043  ...
# 5   165,429,171   169,782,204   174,169,707   178,594,013   183,048,040  ...
#
# ...

# %%
years = ['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970', 
                '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', 
                '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', 
                '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', 
                '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', 
                '2015', '2016', '2017', '2018', '2019', '2020']

continent_pop_change1 = continent_pop.drop(columns=years)

# %%
continent_pop_change1
# Out:
#        Continent  1960 Growth Rate  1961 Growth Rate  1962 Growth Rate  \
# 0         Africa               NaN               NaN               NaN
# 1           Asia               500               492               488
# 2         Europe               -64               -64               -65
# 3  North America               -55               -55               -55
# 4        Oceania               -94               -94               -94
# 5  South America               828               834               836
#
#    1963 Growth Rate  1964 Growth Rate  1965 Growth Rate  1966 Growth Rate  \
# 0               NaN               NaN               NaN               NaN
# 1               487               486               485               485
# 2               -65               -66               -66               -67
# 3               -54               -54               -53               -53
# 4               -94               -94               -94               -94
# ...

# %%
continent_pop.dtypes
# Out:
# Continent     object
# 1960         float64
# 1961         float64
# 1962         float64
# 1963         float64
#               ...
# 2016         float64
# 2017         float64
# 2018         float64
# 2019         float64
# 2020         float64
# Length: 62, dtype: object

# %%
continent_change
# Out:
#        Continent       1961       1962       1963       1964       1965  \
# 0         Africa  6,842,133  7,094,186  7,344,768  7,590,534  7,835,763
# 1           Asia 16,584,670 29,553,667 41,413,879 41,554,939 43,101,817
# 2         Europe  5,842,517  6,070,908  6,117,035  6,040,465  5,817,866
# 3  North America  5,419,065  5,301,242  5,233,248  5,231,289  5,029,640
# 4        Oceania    330,845    402,046    342,287    358,056    353,581
# 5  South America  4,049,151  4,161,697  4,252,674  4,314,141  4,353,033
#
#         1966       1967       1968       1969  ...       2011       2012  \
# 0  8,087,476  8,351,151  8,626,070  8,914,449  ... 27,081,093 24,663,300
# 1 46,961,449 46,771,367 48,269,423 50,507,468  ... 44,463,702 43,805,605
# 2  4,870,830  4,700,628  4,450,936  4,313,848  ...   -316,418  1,272,808
# 3  4,921,698  4,841,389  4,693,451  4,671,572  ...  5,124,725  5,184,175
# 4    402,658    290,354    330,097    378,268  ...    536,374    609,543
# ...

# %%
# Convert the years to integers
continent_change = continent_change.astype({'Continent': str})
continent_change.iloc[:, 1:] = continent_change.iloc[:, 1:].apply(pd.to_numeric, errors='coerce')

# Create a new DataFrame to store the decade sums
decade_sums = pd.DataFrame({'Continent': continent_change['Continent']})

# Create six new columns for each decade's sum
for i in range(1, 7):
    column_name = f'Decade_{i}_Sum'
    year_range = f"{1960 + (i - 1) * 10}-{1969 + (i - 1) * 10}"
    decade_sum = continent_change.iloc[:, (i - 1) * 10 + 1: i * 10 + 1].sum(axis=1)
    decade_sums[year_range] = decade_sum

# %%
continent_change
# Out:
#        Continent       1961       1962       1963       1964       1965  \
# 0         Africa  6,842,133  7,094,186  7,344,768  7,590,534  7,835,763
# 1           Asia 16,584,670 29,553,667 41,413,879 41,554,939 43,101,817
# 2         Europe  5,842,517  6,070,908  6,117,035  6,040,465  5,817,866
# 3  North America  5,419,065  5,301,242  5,233,248  5,231,289  5,029,640
# 4        Oceania    330,845    402,046    342,287    358,056    353,581
# 5  South America  4,049,151  4,161,697  4,252,674  4,314,141  4,353,033
#
#         1966       1967       1968       1969  ...   1980-1989   1990-1999  \
# 0  8,087,476  8,351,151  8,626,070  8,914,449  ... 153,760,846 180,356,625
# 1 46,961,449 46,771,367 48,269,423 50,507,468  ... 552,140,310 527,551,029
# 2  4,870,830  4,700,628  4,450,936  4,313,848  ...  27,310,274   5,646,480
# 3  4,921,698  4,841,389  4,693,451  4,671,572  ...  52,393,519  61,619,366
# 4    402,658    290,354    330,097    378,268  ...   4,056,272   4,245,786
# ...

# %%
decade_sums
# Out:
#        Continent   1960-1969   1970-1979   1980-1989   1990-1999   2000-2009  \
# 0         Africa  79,904,046 112,794,603 153,760,846 180,356,625 228,001,424
# 1           Asia 416,611,629 494,875,284 552,140,310 527,551,029 464,801,485
# 2         Europe  51,989,210  36,820,205  27,310,274   5,646,480   9,099,651
# 3  North America  50,486,626  51,290,108  52,393,519  61,619,366  55,562,278
# 4        Oceania   3,575,152   3,644,915   4,056,272   4,245,786   5,147,920
# 5  South America  43,372,495  48,422,437  54,833,973  52,965,421  43,954,665
#
#     2010-2019
# 0 297,493,959
# 1 426,291,224
# 2  10,284,355
# 3  48,061,271
# 4   6,388,563
# 5  38,438,094

# %%
# Transpose the DataFrame
decade_sums_transposed = decade_sums.set_index('Continent').T

# Set up the figure and axis
fig, ax = plt.subplots(figsize=(10, 6))

# Width of each bar
bar_width = 0.15

# Position of each bar on the x-axis
x_pos = list(range(len(decade_sums_transposed)))

# List of continents
continents = decade_sums_transposed.columns

# Plotting the grouped bars
for i, continent in enumerate(continents):
    x_positions = [pos + i * bar_width for pos in x_pos]
    ax.bar(x_positions, decade_sums_transposed[continent], width=bar_width, label=continent)

# Adjusting x-axis and ticks
ax.set_xticks([pos + 2 * bar_width for pos in x_pos])
ax.set_xticklabels(decade_sums_transposed.index)
ax.set_xlabel('Decades')
ax.set_ylabel('Population')

# Adding a legend
ax.legend()

# Save the plot as a JPEG file
plt.savefig('decade_change_graph.jpg', format='jpeg')

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Checking out the visualization in line graph
# Set up the figure and axis
fig, ax = plt.subplots(figsize=(10, 6))

# Plotting the lines for each continent
for continent in decade_sums_transposed.columns:
    ax.plot(decade_sums_transposed.index, decade_sums_transposed[continent], label=continent)

# Adjusting x-axis and ticks
ax.set_xticks(decade_sums_transposed.index)
ax.set_xlabel('Decades')
ax.set_ylabel('Population')

# Adding a legend
ax.legend()

# Save the plot as a JPEG file
plt.savefig('continental_change2.jpg', format='jpeg')

# Show the plot
plt.tight_layout()
plt.show()

# %%
# List of continents to keep
continents_to_keep = ['Africa', 'Asia']

# Filter the DataFrame to keep only the desired continents
countries_narrowed = dataset_edited.loc[dataset_edited['Continent'].isin(continents_to_keep)]

# %%
countries_narrowed
# Out:
#                 country       1960       1961       1962       1963  \
# 0           Afghanistan  8,996,967  9,169,406  9,351,442  9,543,200
# 2               Algeria 11,057,864 11,336,336 11,619,828 11,912,800
# 5                Angola  5,454,938  5,531,451  5,608,499  5,679,409
# 8               Armenia  1,874,119  1,941,498  2,009,524  2,077,584
# 12           Azerbaijan  3,895,398  4,030,325  4,171,428  4,315,127
# ..                  ...        ...        ...        ...        ...
# 210             Vietnam 32,670,048 33,666,111 34,683,410 35,721,213
# 212  West Bank and Gaza        NaN        NaN        NaN        NaN
# 213         Yemen, Rep.  5,315,351  5,393,034  5,473,671  5,556,767
# 214              Zambia  3,070,780  3,164,330  3,260,645  3,360,099
# 215            Zimbabwe  3,776,679  3,905,038  4,039,209  4,178,726
#
#           1964       1965       1966       1967       1968  ...       2012  \
# ...

# %%
countries_narrowed.Continent.unique()
# Out:
# array(['Asia', 'Africa'], dtype=object)

# %%
# Drop rows with NaN values
countries_narrowed_cleaned = countries_narrowed.dropna()

# %%
# Calculate the total population per country
countries_narrowed_cleaned['Total'] = countries_narrowed_cleaned.iloc[:, 1:].sum(axis=1)

# Sort the DataFrame based on the 'Total' column in descending order
countries_narrowed_cleaned_ranked = countries_narrowed_cleaned.sort_values(by='Total', ascending=False)

# %%
countries_narrowed_cleaned
# Out:
#          country       1960       1961       1962       1963       1964  \
# 0    Afghanistan  8,996,967  9,169,406  9,351,442  9,543,200  9,744,772
# 2        Algeria 11,057,864 11,336,336 11,619,828 11,912,800 12,221,675
# 5         Angola  5,454,938  5,531,451  5,608,499  5,679,409  5,734,995
# 8        Armenia  1,874,119  1,941,498  2,009,524  2,077,584  2,145,004
# 12    Azerbaijan  3,895,398  4,030,325  4,171,428  4,315,127  4,456,691
# ..           ...        ...        ...        ...        ...        ...
# 207   Uzbekistan  8,526,299  8,813,619  9,113,629  9,428,906  9,762,819
# 210      Vietnam 32,670,048 33,666,111 34,683,410 35,721,213 36,780,001
# 213  Yemen, Rep.  5,315,351  5,393,034  5,473,671  5,556,767  5,641,598
# 214       Zambia  3,070,780  3,164,330  3,260,645  3,360,099  3,463,211
# 215     Zimbabwe  3,776,679  3,905,038  4,039,209  4,178,726  4,322,854
#
#           1965       1966       1967       1968  ...       2012       2013  \
# ...

# %%
# Calculate the yearly addition across countries

# Set the 'country' column as the index
countries_narrowed_cleaned.set_index('country', inplace=True)

# Calculate the yearly population changes and remove the first column (1960) from the DataFrame 
countries_narrowed_change = countries_narrowed_cleaned.diff(axis=1)
countries_narrowed_change = countries_narrowed_change.drop(columns='1960')

# Reset the index
countries_narrowed_change.reset_index(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     162     try:
# --> 163         result = func(left, right)
#     164     except TypeError:
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, a, b, use_numexpr)
#     238             # error: "None" not callable
# --> 239             return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     240     return _evaluate_standard(op, op_str, a, b)
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     127     if result is None:
# --> 128         result = _evaluate_standard(op, op_str, a, b)
#     129
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b)
# ...

# %%
countries_narrowed_change
# Out:
#          country    1961      1962      1963      1964      1965      1966  \
# 0    Afghanistan 172,439   182,036   191,758   201,572   211,546   218,522
# 1        Algeria 278,472   283,492   292,972   308,875   329,205   351,746
# 2         Angola  76,513    77,048    70,910    55,586    35,578    10,732
# 3        Armenia  67,379    68,026    68,060    67,420    66,312    64,722
# 4     Azerbaijan 134,927   141,103   143,699   141,564   135,910   128,927
# ..           ...     ...       ...       ...       ...       ...       ...
# 96    Uzbekistan 287,320   300,010   315,277   333,913   354,051   376,571
# 97       Vietnam 996,063 1,017,299 1,037,803 1,058,788 1,078,946 1,099,099
# 98   Yemen, Rep.  77,683    80,637    83,096    84,831    86,147    88,496
# 99        Zambia  93,550    96,315    99,454   103,112   107,255   111,487
# 100     Zimbabwe 128,359   134,171   139,517   144,128   148,324   152,162
#
# ...

# %%
# Convert the years to integers
countries_narrowed_change = countries_narrowed_change.astype({'country': str})
countries_narrowed_change.iloc[:, 1:] = countries_narrowed_change.iloc[:, 1:].apply(pd.to_numeric, errors='coerce')

# Create a new DataFrame to store the decade sums
country_decade_sums = pd.DataFrame({'country': countries_narrowed_change['country']})

# Create six new columns for each decade's sum
for i in range(1, 7):
    column_name = f'Decade_{i}_Sum'
    year_range = f"{1960 + (i - 1) * 10}-{1969 + (i - 1) * 10}"
    country_decade_sum = countries_narrowed_change.iloc[:, (i - 1) * 10 + 1: i * 10 + 1].sum(axis=1)
    country_decade_sums[year_range] = country_decade_sum

# %%
country_decade_sums
# Out:
#          country  1960-1969  1970-1979  1980-1989  1990-1999  2000-2009  \
# 0    Afghanistan  2,176,687  2,182,846   -944,189  8,367,646  8,405,554
# 1        Algeria  3,407,128  4,756,667  6,537,213  5,283,366  4,935,213
# 2         Angola    435,422  2,450,930  3,507,095  4,547,092  6,960,770
# 3        Armenia    650,948    574,692    438,405   -468,567   -192,283
# 4     Azerbaijan  1,284,634    970,703  1,008,265    889,600  1,005,732
# ..           ...        ...        ...        ...        ...        ...
# 96    Uzbekistan  3,554,012  3,818,449  4,611,240  4,140,400  3,912,000
# 97       Vietnam 10,734,754 10,877,039 13,707,014 11,921,556  8,057,244
# 98   Yemen, Rep.    878,028  1,748,524  3,768,084  5,699,084  5,745,783
# 99        Zambia  1,108,282  1,672,756  2,185,031  2,379,093  3,190,044
# 100     Zimbabwe  1,512,633  2,119,318  3,023,779  1,449,073    816,246
#
#      2010-2019
# 0    9,742,830
# 1    7,873,592
# 2    9,510,021
# 3       85,920
# 4    1,055,784
# ...

# %%
# Create a new column 'Continent' and map the values based on the country
country_decade_sums['Continent'] = country_decade_sums['country'].map(country_to_continent)

# %%
country_decade_sums
# Out:
#          country  1960-1969  1970-1979  1980-1989  1990-1999  2000-2009  \
# 0    Afghanistan  2,176,687  2,182,846   -944,189  8,367,646  8,405,554
# 1        Algeria  3,407,128  4,756,667  6,537,213  5,283,366  4,935,213
# 2         Angola    435,422  2,450,930  3,507,095  4,547,092  6,960,770
# 3        Armenia    650,948    574,692    438,405   -468,567   -192,283
# 4     Azerbaijan  1,284,634    970,703  1,008,265    889,600  1,005,732
# ..           ...        ...        ...        ...        ...        ...
# 96    Uzbekistan  3,554,012  3,818,449  4,611,240  4,140,400  3,912,000
# 97       Vietnam 10,734,754 10,877,039 13,707,014 11,921,556  8,057,244
# 98   Yemen, Rep.    878,028  1,748,524  3,768,084  5,699,084  5,745,783
# 99        Zambia  1,108,282  1,672,756  2,185,031  2,379,093  3,190,044
# 100     Zimbabwe  1,512,633  2,119,318  3,023,779  1,449,073    816,246
#
#      2010-2019 Continent
# 0    9,742,830      Asia
# 1    7,873,592    Africa
# ...

# %%
# To move the Continent column to second column just after country

# Get the column name of the last column
last_column_name = country_decade_sums.columns[-1]

# Move the last column to the second position
country_decade_sums = country_decade_sums[[country_decade_sums.columns[0], last_column_name] + country_decade_sums.columns[1:-1].tolist()]

# %%
country_decade_sums
# Out:
#          country       Total Continent  1960-1969  1970-1979  1980-1989  \
# 0    Afghanistan  59,862,748      Asia  2,176,687  2,182,846   -944,189
# 1        Algeria  65,586,358    Africa  3,407,128  4,756,667  6,537,213
# 2         Angola  54,822,660    Africa    435,422  2,450,930  3,507,095
# 3        Armenia   2,178,230      Asia    650,948    574,692    438,405
# 4     Azerbaijan  12,429,436      Asia  1,284,634    970,703  1,008,265
# ..           ...         ...       ...        ...        ...        ...
# 96    Uzbekistan  51,411,502      Asia  3,554,012  3,818,449  4,611,240
# 97       Vietnam 129,337,070      Asia 10,734,754 10,877,039 13,707,014
# 98   Yemen, Rep.  49,021,234      Asia    878,028  1,748,524  3,768,084
# 99        Zambia  30,626,352    Africa  1,108,282  1,672,756  2,185,031
# 100     Zimbabwe  22,172,496    Africa  1,512,633  2,119,318  3,023,779
#
#      1990-1999  2000-2009  2010-2019
# 0    8,367,646  8,405,554  9,742,830
# ...

# %%
# Calculate the total population per country
country_decade_sums['Total'] = country_decade_sums.iloc[:, 1:].sum(axis=1)

# Sort the DataFrame based on the 'Total' column in descending order
country_decade_sums_ranked = country_decade_sums.sort_values(by='Total', ascending=False)
# Out:
# C:\Users\victor.sabo\AppData\Local\Temp\ipykernel_22968\3349291431.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   country_decade_sums['Total'] = country_decade_sums.iloc[:, 1:].sum(axis=1)

# %%
country_decade_sums_ranked.head(10)
# Out:
#              country         Total Continent   1960-1969   1970-1979  \
# 36             India 2,788,370,130      Asia 104,642,122 143,763,040
# 18             China 2,205,126,000      Asia 151,245,000 162,920,000
# 37         Indonesia   557,317,665      Asia  27,042,113  32,654,655
# 70          Pakistan   527,710,923      Asia  13,153,372  19,912,284
# 68           Nigeria   483,003,381    Africa  10,843,682  17,441,504
# 6         Bangladesh   350,027,634      Asia  16,218,981  15,407,012
# 28          Ethiopia   278,436,897    Africa   6,263,796   6,726,623
# 71       Philippines   249,934,032      Asia   9,533,850  11,554,150
# 25  Egypt, Arab Rep.   227,104,536    Africa   7,880,960   8,795,212
# 20  Congo, Dem. Rep.   222,939,444    Africa   4,762,777   6,347,872
#
#      1980-1989   1990-1999   2000-2009   2010-2019
# 36 174,324,962 183,297,749 177,705,615 145,723,222
# 18 153,950,000 127,460,000  75,060,000  64,407,000
# 37  33,965,564  30,100,424  30,320,404  31,689,395
# ...

# %%
country_decade_sums_ranked.to_excel('output4.xlsx', index = False)

# %%
# Retain the first 10 rows
country_first_10 = country_decade_sums_ranked.head(10)

# Set 'country' column as the index
country_first_10.set_index('country', inplace=True)

# Transpose the DataFrame to have decades as columns and countries as rows
country_first_10_transposed = country_first_10.drop(columns=['Continent', 'Total']).T

# Create the line graph
plt.figure(figsize=(10, 6))
for country in country_first_10_transposed.columns:
    plt.plot(country_first_10_transposed.index, country_first_10_transposed[country], label=country)

plt.xlabel('Decades')
plt.ylabel('Population')
plt.title('Population Growth for Countries in Asia and Africa')
plt.legend(loc='upper left')
plt.grid(False)
plt.show()

# %%
# Plot the stacked area chart
ax = country_first_10_transposed.plot.area(figsize=(10, 6), cmap='tab20', alpha=0.7, linewidth=0)

# Customize the plot
ax.set_xlabel('Decades')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# Save the plot as a JPEG file
plt.savefig('country_change.jpg', format='jpeg')

# Show the plot
plt.tight_layout()
plt.show()
